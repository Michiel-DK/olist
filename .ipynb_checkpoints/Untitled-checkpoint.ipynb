# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import os
import seaborn as sns
from stt.order import Order
order = Order().get_training_data()

# %%
    order_count = order.groupby(order['order_delivered_customer_date']\
                .dt.strftime("%y/%m")).agg({'order_id':'nunique','price':'sum'})\
                .rename(columns={'order_id':'Count of orders'})

# %%
order_count
# Out:
#                                Count of orders       price
# order_delivered_customer_date
# 16/10                                      205    30401.12
# 16/11                                       58     9837.68
# 16/12                                        4      758.86
# 17/01                                      283    33815.92
# 17/02                                     1351   200002.92
# 17/03                                     2382   337602.00
# 17/04                                     1849   269623.04
# 17/05                                     3751   522769.38
# 17/06                                     3223   434806.95
# 17/07                                     3455   456824.97
# 17/08                                     4302   539666.25
# 17/09                                     3965   584043.24
# 17/10                                     4494   661019.41
# 17/11                                     4670   654273.49
# 17/12                                     7205   952657.10
# 18/01                                     6597   854811.08
# 18/02                                     5850   754833.85
# 18/03                                     6824   901288.00
# 18/04                                     7850  1114826.91
# 18/05                                     7111  1009830.58
# 18/06                                     6829  1004189.87
# 18/07                                     5839   798024.39
# 18/08                                     8314  1142197.54
# 18/09                                       56    11469.04
# 18/10                                        3      275.40

# %%
sns.catplot(x="review_score", kind="count", data=order)

# %%
from stt.viz import Viz

# %%
Viz().top_category()

# %%
Viz().order_viz()

# %%
Viz().top_geo()

# %%
Viz().profit_viz()

# %%
from stt.viz import Viz
from stt.profitability import Profitability

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
prof = Profitability().merge_table()

# %%
small = prof[['profit','profitable']].sort_values(by='profit')

# %%
small.reset_index(drop=True, inplace=True)

# %%
small
# Out:
#         profit  profitable
# 0    -25486.08           0
# 1    -24679.52           0
# 2    -23847.61           0
# 3    -22612.71           0
# 4    -17172.25           0
# ...        ...         ...
# 2965   7338.46           1
# 2966   7571.12           1
# 2967  14804.20           1
# 2968  15963.19           1
# 2969  17787.60           1
#
# [2970 rows x 2 columns]

# %%
prof
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 2965  98dddbc4601dd4443ca174359b237166                   87111
# 2966  f8201cab383e484733266d1906e2fdfa                   88137
# 2967  74871d19219c7d518d0090283e03c137                    4650
# 2968  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 2969  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state  delay_to_carrier  wait_time  \
# 0              campinas           SP              0.00      13.02
# 1            mogi guacu           SP              0.00       9.07
# 2        rio de janeiro           RJ              0.00       4.04
# 3             sao paulo           SP              0.00       5.67
# 4     braganca paulista           SP              3.35      35.31
# ...                 ...          ...               ...        ...
# 2965            sarandi           PR              0.00       8.23
# 2966            palhoca           SC              0.00      13.05
# 2967          sao paulo           SP              0.00       3.61
# 2968            pelotas           RS              0.00       6.66
# 2969            taubate           SP              0.00       8.20
#
#      date_first_sale date_last_sale  share_one_stars  share_of_five_stars  \
# 0         2017-05-05     2017-08-30             0.33                 0.33
# 1         2017-03-29     2018-06-06             0.05                 0.72
# 2         2018-07-30     2018-07-30             0.00                 1.00
# 3         2018-08-03     2018-08-03             0.00                 1.00
# 4         2017-11-14     2017-11-14             1.00                 0.00
# ...              ...            ...              ...                  ...
# 2965      2018-07-14     2018-07-23             0.00                 1.00
# 2966      2017-06-17     2018-08-11             0.10                 0.50
# 2967      2018-04-05     2018-08-21             0.00                 1.00
# 2968      2017-02-09     2017-06-16             0.00                 0.50
# 2969      2017-03-27     2017-03-27             0.00                 0.00
#
#       ...  n_orders  quantity     sales  active_months  cost_reviews  \
# 0     ...         3         3    218.70            4.0           140
# 1     ...        40        41  11703.07           14.0           140
# 2     ...         1         1    158.00            1.0             0
# 3     ...         1         1     79.99            1.0             0
# 4     ...         1         1    167.99            1.0           100
# ...   ...       ...       ...       ...            ...           ...
# 2965  ...         2         2    158.00            1.0             0
# 2966  ...        10        10    889.00           14.0           140
# 2967  ...         6         7    550.04            5.0             0
# 2968  ...         8        11    297.00            4.0             0
# 2969  ...         1         1     12.50            1.0             0
#
#       rev_seller  rev_orders  total_rev   profit  profitable
# 0          320.0       21.87     341.87   201.87           1
# 1         1120.0     1170.31    2290.31  2150.31           1
# 2           80.0       15.80      95.80    95.80           1
# 3           80.0        8.00      88.00    88.00           1
# 4           80.0       16.80      96.80    -3.20           0
# ...          ...         ...        ...      ...         ...
# 2965        80.0       15.80      95.80    95.80           1
# 2966      1120.0       88.90    1208.90  1068.90           1
# 2967       400.0       55.00     455.00   455.00           1
# 2968       320.0       29.70     349.70   349.70           1
# 2969        80.0        1.25      81.25    81.25           1
#
# [2970 rows x 21 columns]

# %%
prof = prof[['seller_id','n_orders','rev_seller','rev_orders','cost_reviews','profit']]

# %%
sorted_profit = prof.sort_values('profit').reset_index()

# %%
sorted_profit
# Out:
#       index                         seller_id  n_orders  rev_seller  \
# 0       453  1f50f920176fa81dab994f9023523100      1404      1360.0
# 1       769  6560211a19b47992c3666cc44a7e94c0      1854      1520.0
# 2      1133  7c67e1448b00f6e969d365cea6b010ab       982      1520.0
# 3      2360  4a3ca9315b744ce9f8e9374361493884      1806      1600.0
# 4       946  ea8482cd71df3c1969d7b9473ff13abc      1146       960.0
# ...     ...                               ...       ...         ...
# 2965   2153  edb1ef5e36e0c8cd84eb3c9b003e486d       166       880.0
# 2966   2833  46dc3b2cc0980fb8ec44634e21d2718e       521      1840.0
# 2967    534  fa1c13f2614d7b5c4749cbc52fecda94       585      1600.0
# 2968     67  7e93a43ef30c4f03f38b393420bc753a       336      1680.0
# 2969    868  53243585a1d6dc2643021fd1853d8905       358       960.0
#
#       rev_orders  cost_reviews    profit
# 0       10693.92         37540 -25486.08
# 1       12330.48         38530 -24679.52
# 2       18792.39         44160 -23847.61
# 3       20047.29         44260 -22612.71
# 4        3717.75         21850 -17172.25
# ...          ...           ...       ...
# 2965     7928.46          1470   7338.46
# 2966    12811.12          7080   7571.12
# 2967    19404.20          6200  14804.20
# 2968    17643.19          3360  15963.19
# 2969    22277.60          5450  17787.60
#
# [2970 rows x 7 columns]

# %%
sorted_profit['cum_orders'] = sorted_profit['n_orders'].cumsum()
sorted_profit['cum_rev_seller'] = sorted_profit['rev_seller'].cumsum()
sorted_profit['cum_rev_orders'] = sorted_profit['rev_orders'].cumsum()
sorted_profit['cum_cost_reviews'] = (sorted_profit['cost_reviews'].cumsum())*-1
sorted_profit['cum_rev'] = sorted_profit['profit'].cumsum()
c = 500000/np.sqrt(sorted_profit['n_orders'].sum())
sorted_profit['cum_it_cost'] = (round(c * np.sqrt(sorted_profit["cum_orders"]),2))*-1
sorted_profit['cum_profit'] = round(sorted_profit['cum_rev'] + sorted_profit['cum_it_cost'],2)

# %%
sorted_profit
# Out:
#       index                         seller_id  n_orders  rev_seller  \
# 0       453  1f50f920176fa81dab994f9023523100      1404      1360.0
# 1       769  6560211a19b47992c3666cc44a7e94c0      1854      1520.0
# 2      1133  7c67e1448b00f6e969d365cea6b010ab       982      1520.0
# 3      2360  4a3ca9315b744ce9f8e9374361493884      1806      1600.0
# 4       946  ea8482cd71df3c1969d7b9473ff13abc      1146       960.0
# ...     ...                               ...       ...         ...
# 2965   2153  edb1ef5e36e0c8cd84eb3c9b003e486d       166       880.0
# 2966   2833  46dc3b2cc0980fb8ec44634e21d2718e       521      1840.0
# 2967    534  fa1c13f2614d7b5c4749cbc52fecda94       585      1600.0
# 2968     67  7e93a43ef30c4f03f38b393420bc753a       336      1680.0
# 2969    868  53243585a1d6dc2643021fd1853d8905       358       960.0
#
#       rev_orders  cost_reviews    profit  cum_orders  cum_rev_seller  \
# 0       10693.92         37540 -25486.08        1404          1360.0
# 1       12330.48         38530 -24679.52        3258          2880.0
# 2       18792.39         44160 -23847.61        4240          4400.0
# 3       20047.29         44260 -22612.71        6046          6000.0
# 4        3717.75         21850 -17172.25        7192          6960.0
# ...          ...           ...       ...         ...             ...
# 2965     7928.46          1470   7338.46       98044       1495600.0
# 2966    12811.12          7080   7571.12       98565       1497440.0
# 2967    19404.20          6200  14804.20       99150       1499040.0
# 2968    17643.19          3360  15963.19       99486       1500720.0
# 2969    22277.60          5450  17787.60       99844       1501680.0
#
#       cum_rev_orders  cum_cost_reviews    cum_rev  cum_it_cost  cum_profit
# 0           10693.92            -37540  -25486.08    -59291.52   -84777.60
# 1           23024.40            -76070  -50165.60    -90320.13  -140485.73
# 2           41816.79           -120230  -74013.21   -103036.70  -177049.91
# 3           61864.08           -164490  -96625.92   -123039.08  -219665.00
# 4           65581.83           -186340 -113798.17   -134194.23  -247992.40
# ...              ...               ...        ...          ...         ...
# 2965      1284119.59          -1846310  933409.43   -495472.47   437936.96
# 2966      1296930.71          -1853390  940980.55   -496787.18   444193.37
# 2967      1316334.91          -1859590  955784.75   -498259.26   457525.49
# 2968      1333978.10          -1862950  971747.94   -499102.80   472645.14
# 2969      1356255.70          -1868400  989535.54   -500000.00   489535.54
#
# [2970 rows x 14 columns]

# %%
plt.plot(sorted_profit[['cum_rev_seller','cum_rev_orders','cum_cost_reviews','cum_it_cost','cum_profit']])
plt.legend(labels=['cum_rev_seller','cum_rev_orders','cum_cost_reviews','cum_it_cost','cum_profit'])

# %%
plt.figure(figsize=(40,20))
plt.title('Lifetime cumulative revenue and costs sorted from least to most profitable seller', fontsize=40)
plt.bar(sorted_profit.index, sorted_profit['cum_rev_seller'], label='Revenue sellers')
plt.bar(sorted_profit.index, sorted_profit['cum_rev_orders'], bottom=sorted_profit['cum_rev_seller'], label = 'Revenue orders')
plt.bar(sorted_profit.index, sorted_profit['cum_it_cost'], label='IT cost')
plt.bar(sorted_profit.index, sorted_profit['cum_cost_reviews'], bottom=sorted_profit['cum_it_cost'], label = 'Review cost')
plt.plot(sorted_profit['cum_profit'], c='w',linewidth=7.0 , linestyle='--', label = 'Profit')
#plt.legend(labels=['Revenue sellers', 'Revenue orders', 'IT cost', 'Review cost', 'Profit'])
plt.xlabel('Sellers', fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('100k BRL', fontsize=20)
# Show the major grid lines with dark grey lines
plt.grid(b=True, which='major', color='#666666', linestyle='-')
# Show the minor grid lines with very faint and almost transparent grey lines
plt.minorticks_on()
plt.grid(b=True, which='minor', color='#999999', linestyle='-', alpha=0.2)
