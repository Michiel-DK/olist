# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from stt.profitability import Profitability

# %%
profit = Profitability().merge_table()

# %%
optim_df = Profitability().optim_df()

# %%
to_cut = Profitability().optim_df()[1]

# %%
optim_df
# Out:
#       index                         seller_id  n_orders  rev_seller  \
# 375    2709  1588ac4010787100dddef64568f0ae35         3        80.0
# 376    1167  19484c79cef6c062cb177aa4ef2fcc3c         1        80.0
# 377    1844  01fd077212124329bac32490e8ef80d9        31       320.0
# 378    1487  f593898ec748b7a8cb81fc04edafd98a        20       400.0
# 379    1972  a4b8d97cd5d3674eeff96abc99d8ed67         1        80.0
# ...     ...                               ...       ...         ...
# 2965   2153  edb1ef5e36e0c8cd84eb3c9b003e486d       166       880.0
# 2966   2833  46dc3b2cc0980fb8ec44634e21d2718e       521      1840.0
# 2967    534  fa1c13f2614d7b5c4749cbc52fecda94       585      1600.0
# 2968     67  7e93a43ef30c4f03f38b393420bc753a       336      1680.0
# 2969    868  53243585a1d6dc2643021fd1853d8905       358       960.0
#
#       rev_orders  cost_reviews    profit  cum_orders  cum_rev_seller  \
# 375        60.00           140     -0.00           3            80.0
# ...
