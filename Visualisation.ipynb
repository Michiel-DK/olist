# %%
from stt.viz import Viz
# %matplotlib inline

# %%
Viz().order_viz()

# %% [markdown]
# >> Steady increase in volume throughout existence <br>
# >> Beginning of the week busiest regarding orders purchased

# %%
Viz().top_category()

# %% [markdown]
# >> Top categories change lightly when considering volume

# %%
Viz().top_geo()

# %% [markdown]
# >> Biggest majority of sales in Sao Paolo (state and city)

# %%
Viz().delivery_viz()

# %% [markdown]
# >> Logistical performance quite strong - in general actual delivery time < expected

# %% [markdown]
# ## Profitability

# %% [markdown]
# >> Profitability calculated based on below assumptions: <br>
# >>> Revenue <br>
# >>>> -> Olist takes a 10% cut on the product price (excl. freight) of each order delivered. <br>
# >>>> -> Olist charges 80 BRL by month per seller.<br>
#
# >>> Cost <br>
# >>>> -> 1, 2 and 3 stars review - respectively 100, 50 and 40 BRL incurred <br>
# >>>> -> total cumulated IT Costs to be proportional to the square-root of the total cumulated number of orders processed. Since the birth of the marketplace, cumulated IT costs have amounted to 500,000 BRL.

# %%
Viz().profit_viz()

# %%
from stt.profitability import Profitability

# %%
Profitability().optimisation()
# Out:
# (      companies to cut                         seller_id      profit
#  0                    0  1f50f920176fa81dab994f9023523100  1489535.54
#  1                    1  6560211a19b47992c3666cc44a7e94c0   515021.60
#  2                    2  7c67e1448b00f6e969d365cea6b010ab   539701.10
#  3                    3  4a3ca9315b744ce9f8e9374361493884   563548.80
#  4                    4  ea8482cd71df3c1969d7b9473ff13abc   586161.50
#  ...                ...                               ...         ...
#  2964              2964  ccc4bbb5f32a6ab2b7066a4130f114e3  -429645.00
#  2965              2965  edb1ef5e36e0c8cd84eb3c9b003e486d  -436535.40
#  2966              2966  46dc3b2cc0980fb8ec44634e21d2718e  -443873.90
#  2967              2967  fa1c13f2614d7b5c4749cbc52fecda94  -451445.00
#  2968              2968  7e93a43ef30c4f03f38b393420bc753a  -466249.20
#
#  [2969 rows x 3 columns],
#        index                         seller_id  n_orders  rev_seller  \
#  2969    868  53243585a1d6dc2643021fd1853d8905       358       960.0
#
#        rev_orders  cost_reviews   profit  cum_orders  cum_rev_seller  \
#  2969     22277.6          5450  17787.6         358       1501680.0
#
#        cum_rev_orders  cum_cost_reviews  cum_rev  cum_it_cost  cum_profit  \
#  2969       1356255.7          -1868400  17787.6     500000.0   -482212.4
#
#         it_cost   prof/it
#  2969  500000.0  0.035575  )

# %%
Profitability().optim_df()
# Out:
# /Users/admin/code/Michiel-DK/olist/stt/profitability.py:137: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   new_df = sorted_profit[sorted_profit_cut['cut'] != 'cut']
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-3-55a01706f47c> in <module>
# ----> 1 Profitability().optim_df()
#
# ~/code/Michiel-DK/olist/stt/profitability.py in optim_df(self)
#     135         to_cut['cut'] = "cut"
#     136         sorted_profit_cut = sorted_profit.merge(to_cut, on = 'seller_id', how = 'left')
# --> 137         new_df = sorted_profit[sorted_profit_cut['cut'] != 'cut']
#     138
#     139         return new_df
#
# ~/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3013         # Do we have a (boolean) 1d indexer?
#    3014         if com.is_bool_indexer(key):
# -> 3015             return self._getitem_bool_array(key)
#    3016
#    3017         # We are left with two options: a single key, and a collection of keys,
#
# ~/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    3066         # check_bool_indexer will throw exception if Series key cannot
#    3067         # be reindexed to match DataFrame rows
# -> 3068         key = check_bool_indexer(self.index, key)
#    3069         indexer = key.nonzero()[0]
#    3070         return self._take_with_is_copy(indexer, axis=0)
#
# ~/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pandas/core/indexing.py in check_bool_indexer(index, key)
#    2268         if mask.any():
#    2269             raise IndexingError(
# -> 2270                 "Unalignable boolean Series provided as "
#    2271                 "indexer (index of the boolean Series and of "
#    2272                 "the indexed object do not match)."
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).
