# %%
import pandas as pd
import mlxtend
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
df = pd.read_csv('data_ecom.csv')

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
len(df['InvoiceNo'].unique()), len(df['Description'].unique())
# Out:
# (25900, 4224)

# %%
# Stripping extra spaces in the description
df['Description'] = df['Description'].str.strip()
  
# Dropping the rows without any invoice number
df.dropna(axis = 0, subset =['InvoiceNo'], inplace = True)
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
  
# Dropping all transactions which were done on credit
df = df[~df['InvoiceNo'].str.contains('C')]

# %%
basket = df.groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo')

# %%
basket
# Out:
# Description  *Boombox Ipod Classic  *USB Office Mirror Ball  \
# InvoiceNo
# 536365                         0.0                      0.0
# 536366                         0.0                      0.0
# 536367                         0.0                      0.0
# 536368                         0.0                      0.0
# 536369                         0.0                      0.0
# ...                            ...                      ...
# 581586                         0.0                      0.0
# 581587                         0.0                      0.0
# A563185                        0.0                      0.0
# A563186                        0.0                      0.0
# A563187                        0.0                      0.0
#
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536365                          0.0                         0.0
# 536366                          0.0                         0.0
# 536367                          0.0                         0.0
# 536368                          0.0                         0.0
# 536369                          0.0                         0.0
# ...                             ...                         ...
# 581586                          0.0                         0.0
# 581587                          0.0                         0.0
# A563185                         0.0                         0.0
# A563186                         0.0                         0.0
# A563187                         0.0                         0.0
#
# Description  12 DAISY PEGS IN WOOD BOX  12 EGG HOUSE PAINTED WOOD  \
# InvoiceNo
# 536365                             0.0                        0.0
# 536366                             0.0                        0.0
# 536367                             0.0                        0.0
# 536368                             0.0                        0.0
# 536369                             0.0                        0.0
# ...                                ...                        ...
# 581586                             0.0                        0.0
# 581587                             0.0                        0.0
# A563185                            0.0                        0.0
# A563186                            0.0                        0.0
# A563187                            0.0                        0.0
#
# Description  12 HANGING EGGS HAND PAINTED  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536365                                0.0                               0.0
# 536366                                0.0                               0.0
# 536367                                0.0                               0.0
# 536368                                0.0                               0.0
# 536369                                0.0                               0.0
# ...                                   ...                               ...
# 581586                                0.0                               0.0
# 581587                                0.0                               0.0
# A563185                               0.0                               0.0
# A563186                               0.0                               0.0
# A563187                               0.0                               0.0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536365                                   0.0                            0.0
# 536366                                   0.0                            0.0
# 536367                                   0.0                            0.0
# 536368                                   0.0                            0.0
# 536369                                   0.0                            0.0
# ...                                      ...                            ...
# 581586                                   0.0                            0.0
# 581587                                   0.0                            0.0
# A563185                                  0.0                            0.0
# A563186                                  0.0                            0.0
# A563187                                  0.0                            0.0
#
# Description  ...  wrongly coded 20713  wrongly coded 23343  \
# InvoiceNo    ...
# 536365       ...                  0.0                  0.0
# 536366       ...                  0.0                  0.0
# 536367       ...                  0.0                  0.0
# 536368       ...                  0.0                  0.0
# 536369       ...                  0.0                  0.0
# ...          ...                  ...                  ...
# 581586       ...                  0.0                  0.0
# 581587       ...                  0.0                  0.0
# A563185      ...                  0.0                  0.0
# A563186      ...                  0.0                  0.0
# A563187      ...                  0.0                  0.0
#
# Description  wrongly coded-23343  wrongly marked  wrongly marked 23343  \
# InvoiceNo
# 536365                       0.0             0.0                   0.0
# 536366                       0.0             0.0                   0.0
# 536367                       0.0             0.0                   0.0
# 536368                       0.0             0.0                   0.0
# 536369                       0.0             0.0                   0.0
# ...                          ...             ...                   ...
# 581586                       0.0             0.0                   0.0
# 581587                       0.0             0.0                   0.0
# A563185                      0.0             0.0                   0.0
# A563186                      0.0             0.0                   0.0
# A563187                      0.0             0.0                   0.0
#
# Description  wrongly marked carton 22804  wrongly marked. 23343 in box  \
# InvoiceNo
# 536365                               0.0                           0.0
# 536366                               0.0                           0.0
# 536367                               0.0                           0.0
# 536368                               0.0                           0.0
# 536369                               0.0                           0.0
# ...                                  ...                           ...
# 581586                               0.0                           0.0
# 581587                               0.0                           0.0
# A563185                              0.0                           0.0
# A563186                              0.0                           0.0
# A563187                              0.0                           0.0
#
# Description  wrongly sold (22719) barcode  wrongly sold as sets  \
# InvoiceNo
# 536365                                0.0                   0.0
# 536366                                0.0                   0.0
# 536367                                0.0                   0.0
# 536368                                0.0                   0.0
# 536369                                0.0                   0.0
# ...                                   ...                   ...
# 581586                                0.0                   0.0
# 581587                                0.0                   0.0
# A563185                               0.0                   0.0
# A563186                               0.0                   0.0
# A563187                               0.0                   0.0
#
# Description  wrongly sold sets
# InvoiceNo
# 536365                     0.0
# 536366                     0.0
# 536367                     0.0
# 536368                     0.0
# 536369                     0.0
# ...                        ...
# 581586                     0.0
# 581587                     0.0
# A563185                    0.0
# A563186                    0.0
# A563187                    0.0
#
# [20610 rows x 4195 columns]

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

basket_sets = basket.applymap(encode_units)

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.05, use_colnames=True)
frequent_itemsets
# Out:
#      support                              itemsets
# 0   0.050995            (ALARM CLOCK BAKELIKE RED)
# 1   0.070597       (ASSORTED COLOUR BIRD ORNAMENT)
# 2   0.058273               (HEART OF WICKER SMALL)
# 3   0.056380              (JAM MAKING SET PRINTED)
# 4   0.054973            (JAM MAKING SET WITH JARS)
# 5   0.059098             (JUMBO BAG PINK POLKADOT)
# 6   0.101504             (JUMBO BAG RED RETROSPOT)
# 7   0.057011   (JUMBO SHOPPER VINTAGE RED PAISLEY)
# 8   0.057448              (JUMBO STORAGE BAG SUKI)
# 9   0.061766             (LUNCH BAG  BLACK SKULL.)
# 10  0.050267              (LUNCH BAG APPLE DESIGN)
# 11  0.055798                 (LUNCH BAG CARS BLUE)
# 12  0.052887             (LUNCH BAG PINK POLKADOT)
# 13  0.075885             (LUNCH BAG RED RETROSPOT)
# 14  0.056138           (LUNCH BAG SPACEBOY DESIGN)
# 15  0.052644               (LUNCH BAG SUKI DESIGN)
# 16  0.060602      (NATURAL SLATE HEART CHALKBOARD)
# 17  0.064047     (PACK OF 72 RETROSPOT CAKE CASES)
# 18  0.056283      (PAPER CHAIN KIT 50'S CHRISTMAS)
# 19  0.081805                       (PARTY BUNTING)
# 20  0.054634                             (POSTAGE)
# 21  0.054197     (RECIPE BOX PANTRY YELLOW DESIGN)
# 22  0.050170         (RED RETROSPOT CHARLOTTE BAG)
# 23  0.096507            (REGENCY CAKESTAND 3 TIER)
# 24  0.051722     (ROSES REGENCY TEACUP AND SAUCER)
# 25  0.067200    (SET OF 3 CAKE TINS PANTRY DESIGN)
# 26  0.052062        (SET OF 4 PANTRY JELLY MOULDS)
# 27  0.055361                      (SPOTTY BUNTING)
# 28  0.050315     (VICTORIAN GLASS HANGING T-LIGHT)
# 29  0.109656  (WHITE HANGING HEART T-LIGHT HOLDER)
# 30  0.053372   (WOODEN PICTURE FRAME WHITE FINISH)

# %%
rules = association_rules(frequent_itemsets, metric ="lift", min_threshold = 1)
rules
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %%
basket_France = (df[df['Country'] =="France"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
basket_France = basket_France.applymap(encode_units)

# %%
frq_items = apriori(basket_France, min_support = 0.05, use_colnames = True)
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
rules
# Out:
#                                            antecedents  \
# 44                        (JUMBO BAG WOODLAND ANIMALS)
# 258  (PLASTERS IN TIN CIRCUS PARADE, RED TOADSTOOL ...
# 270  (PLASTERS IN TIN WOODLAND ANIMALS, RED TOADSTO...
# 302  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 300  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
# ..                                                 ...
# 37                                           (POSTAGE)
# 26                                           (POSTAGE)
# 97                                           (POSTAGE)
# 227                                          (POSTAGE)
# 214                                          (POSTAGE)
#
#                                            consequents  antecedent support  \
# 44                                           (POSTAGE)            0.076531
# 258                                          (POSTAGE)            0.051020
# 270                                          (POSTAGE)            0.053571
# 302                    (SET/6 RED SPOTTY PAPER PLATES)            0.102041
# 300                      (SET/6 RED SPOTTY PAPER CUPS)            0.102041
# ..                                                 ...                 ...
# 37                            (JAM MAKING SET PRINTED)            0.765306
# 26                   (CIRCUS PARADE CHILDRENS EGG CUP)            0.765306
# 97                                     (PARTY BUNTING)            0.765306
# 227      (LUNCH BAG RED RETROSPOT, LUNCH BAG WOODLAND)            0.765306
# 214  (LUNCH BAG APPLE DESIGN, LUNCH BAG SPACEBOY DE...            0.765306
#
#      consequent support   support  confidence      lift  leverage  conviction
# 44             0.765306  0.076531    1.000000  1.306667  0.017961         inf
# 258            0.765306  0.051020    1.000000  1.306667  0.011974         inf
# 270            0.765306  0.053571    1.000000  1.306667  0.012573         inf
# 302            0.127551  0.099490    0.975000  7.644000  0.086474   34.897959
# 300            0.137755  0.099490    0.975000  7.077778  0.085433   34.489796
# ..                  ...       ...         ...       ...       ...         ...
# 37             0.053571  0.051020    0.066667  1.244444  0.010022    1.014031
# 26             0.056122  0.051020    0.066667  1.187879  0.008070    1.011297
# 97             0.056122  0.051020    0.066667  1.187879  0.008070    1.011297
# 227            0.056122  0.051020    0.066667  1.187879  0.008070    1.011297
# 214            0.063776  0.051020    0.066667  1.045333  0.002213    1.003098
#
# [348 rows x 9 columns]

# %% [markdown]
# Support is the relative frequency that the rules show up. In many instances, you may want to look for high support in order to make sure it is a useful relationship. However, there may be instances where a low support is useful if you are trying to find “hidden” relationships.
#
# Confidence is a measure of the reliability of the rule. A confidence of .5 in the above example would mean that in 50% of the cases where Diaper and Gum were purchased, the purchase also included Beer and Chips. For product recommendation, a 50% confidence may be perfectly acceptable but in a medical situation, this level may not be high enough.
#
# Lift is the ratio of the observed support to that expected if the two rules were independent (see wikipedia). The basic rule of thumb is that a lift value close to 1 means the rules were completely independent. Lift values > 1 are generally more “interesting” and could be indicative of a useful rule pattern.

# %%
rules.loc[(rules['confidence']>0.5) & (rules['lift']>1.0)]
# Out:
#                                            antecedents  \
# 44                        (JUMBO BAG WOODLAND ANIMALS)
# 258  (PLASTERS IN TIN CIRCUS PARADE, RED TOADSTOOL ...
# 270  (PLASTERS IN TIN WOODLAND ANIMALS, RED TOADSTO...
# 302  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 300  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
# ..                                                 ...
# 83                 (STRAWBERRY LUNCH BOX WITH CUTLERY)
# 327  (PLASTERS IN TIN SPACEBOY, PLASTERS IN TIN WOO...
# 235        (LUNCH BOX WITH CUTLERY RETROSPOT, POSTAGE)
# 236       (STRAWBERRY LUNCH BOX WITH CUTLERY, POSTAGE)
# 48                            (LUNCH BAG APPLE DESIGN)
#
#                                   consequents  antecedent support  \
# 44                                  (POSTAGE)            0.076531
# 258                                 (POSTAGE)            0.051020
# 270                                 (POSTAGE)            0.053571
# 302           (SET/6 RED SPOTTY PAPER PLATES)            0.102041
# 300             (SET/6 RED SPOTTY PAPER CUPS)            0.102041
# ..                                        ...                 ...
# 83         (LUNCH BOX WITH CUTLERY RETROSPOT)            0.122449
# 327  (PLASTERS IN TIN CIRCUS PARADE, POSTAGE)            0.104592
# 235       (STRAWBERRY LUNCH BOX WITH CUTLERY)            0.114796
# 236        (LUNCH BOX WITH CUTLERY RETROSPOT)            0.114796
# 48                (LUNCH BAG SPACEBOY DESIGN)            0.125000
#
#      consequent support   support  confidence      lift  leverage  conviction
# 44             0.765306  0.076531    1.000000  1.306667  0.017961         inf
# 258            0.765306  0.051020    1.000000  1.306667  0.011974         inf
# 270            0.765306  0.053571    1.000000  1.306667  0.012573         inf
# 302            0.127551  0.099490    0.975000  7.644000  0.086474   34.897959
# 300            0.137755  0.099490    0.975000  7.077778  0.085433   34.489796
# ..                  ...       ...         ...       ...       ...         ...
# 83             0.142857  0.063776    0.520833  3.645833  0.046283    1.788820
# 327            0.147959  0.053571    0.512195  3.461733  0.038096    1.746684
# 235            0.122449  0.058673    0.511111  4.174074  0.044617    1.794991
# 236            0.142857  0.058673    0.511111  3.577778  0.042274    1.753247
# 48             0.119898  0.063776    0.510204  4.255319  0.048788    1.796875
#
# [198 rows x 9 columns]
