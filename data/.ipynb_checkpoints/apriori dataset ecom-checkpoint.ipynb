# %%
import pandas as pd
import mlxtend
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial.distance import euclidean, cityblock
import random
import seaborn as sns

# %%
df = pd.read_csv('data_ecom.csv')

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
#summary 
len(df['InvoiceNo'].unique()), len(df['StockCode'].unique())
# Out:
# (25900, 4070)

# %%
# Stripping extra spaces in the description
df['Description'] = df['Description'].str.strip()
  
# Dropping the rows without any invoice number
df.dropna(axis = 0, subset =['InvoiceNo'], inplace = True)
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
  
# Dropping all transactions which were done on credit
df = df[~df['InvoiceNo'].str.contains('C')]

# %%
#prepare basket for apriori
basket = df.groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo')

# %%
basket.head()
# Out:
# Description  *Boombox Ipod Classic  *USB Office Mirror Ball  \
# InvoiceNo
# 536365                         0.0                      0.0
# 536366                         0.0                      0.0
# 536367                         0.0                      0.0
# 536368                         0.0                      0.0
# 536369                         0.0                      0.0
#
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536365                          0.0                         0.0
# 536366                          0.0                         0.0
# 536367                          0.0                         0.0
# 536368                          0.0                         0.0
# 536369                          0.0                         0.0
#
# Description  12 DAISY PEGS IN WOOD BOX  12 EGG HOUSE PAINTED WOOD  \
# InvoiceNo
# 536365                             0.0                        0.0
# 536366                             0.0                        0.0
# 536367                             0.0                        0.0
# 536368                             0.0                        0.0
# 536369                             0.0                        0.0
#
# Description  12 HANGING EGGS HAND PAINTED  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536365                                0.0                               0.0
# 536366                                0.0                               0.0
# 536367                                0.0                               0.0
# 536368                                0.0                               0.0
# 536369                                0.0                               0.0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536365                                   0.0                            0.0
# 536366                                   0.0                            0.0
# 536367                                   0.0                            0.0
# 536368                                   0.0                            0.0
# 536369                                   0.0                            0.0
#
# Description  ...  wrongly coded 20713  wrongly coded 23343  \
# InvoiceNo    ...
# 536365       ...                  0.0                  0.0
# 536366       ...                  0.0                  0.0
# 536367       ...                  0.0                  0.0
# 536368       ...                  0.0                  0.0
# 536369       ...                  0.0                  0.0
#
# Description  wrongly coded-23343  wrongly marked  wrongly marked 23343  \
# InvoiceNo
# 536365                       0.0             0.0                   0.0
# 536366                       0.0             0.0                   0.0
# 536367                       0.0             0.0                   0.0
# 536368                       0.0             0.0                   0.0
# 536369                       0.0             0.0                   0.0
#
# Description  wrongly marked carton 22804  wrongly marked. 23343 in box  \
# InvoiceNo
# 536365                               0.0                           0.0
# 536366                               0.0                           0.0
# 536367                               0.0                           0.0
# 536368                               0.0                           0.0
# 536369                               0.0                           0.0
#
# Description  wrongly sold (22719) barcode  wrongly sold as sets  \
# InvoiceNo
# 536365                                0.0                   0.0
# 536366                                0.0                   0.0
# 536367                                0.0                   0.0
# 536368                                0.0                   0.0
# 536369                                0.0                   0.0
#
# Description  wrongly sold sets
# InvoiceNo
# 536365                     0.0
# 536366                     0.0
# 536367                     0.0
# 536368                     0.0
# 536369                     0.0
#
# [5 rows x 4195 columns]

# %%
#hot encode
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

basket_sets = basket.applymap(encode_units)

# %%
# get frequent items on support
frequent_itemsets = apriori(basket_sets, min_support=0.05, use_colnames=True)
frequent_itemsets
# Out:
#      support                              itemsets
# 0   0.050995            (ALARM CLOCK BAKELIKE RED)
# 1   0.070597       (ASSORTED COLOUR BIRD ORNAMENT)
# 2   0.058273               (HEART OF WICKER SMALL)
# 3   0.056380              (JAM MAKING SET PRINTED)
# 4   0.054973            (JAM MAKING SET WITH JARS)
# 5   0.059098             (JUMBO BAG PINK POLKADOT)
# 6   0.101504             (JUMBO BAG RED RETROSPOT)
# 7   0.057011   (JUMBO SHOPPER VINTAGE RED PAISLEY)
# 8   0.057448              (JUMBO STORAGE BAG SUKI)
# 9   0.061766             (LUNCH BAG  BLACK SKULL.)
# 10  0.050267              (LUNCH BAG APPLE DESIGN)
# 11  0.055798                 (LUNCH BAG CARS BLUE)
# 12  0.052887             (LUNCH BAG PINK POLKADOT)
# 13  0.075885             (LUNCH BAG RED RETROSPOT)
# 14  0.056138           (LUNCH BAG SPACEBOY DESIGN)
# 15  0.052644               (LUNCH BAG SUKI DESIGN)
# 16  0.060602      (NATURAL SLATE HEART CHALKBOARD)
# 17  0.064047     (PACK OF 72 RETROSPOT CAKE CASES)
# 18  0.056283      (PAPER CHAIN KIT 50'S CHRISTMAS)
# 19  0.081805                       (PARTY BUNTING)
# 20  0.054634                             (POSTAGE)
# 21  0.054197     (RECIPE BOX PANTRY YELLOW DESIGN)
# 22  0.050170         (RED RETROSPOT CHARLOTTE BAG)
# 23  0.096507            (REGENCY CAKESTAND 3 TIER)
# 24  0.051722     (ROSES REGENCY TEACUP AND SAUCER)
# 25  0.067200    (SET OF 3 CAKE TINS PANTRY DESIGN)
# 26  0.052062        (SET OF 4 PANTRY JELLY MOULDS)
# 27  0.055361                      (SPOTTY BUNTING)
# 28  0.050315     (VICTORIAN GLASS HANGING T-LIGHT)
# 29  0.109656  (WHITE HANGING HEART T-LIGHT HOLDER)
# 30  0.053372   (WOODEN PICTURE FRAME WHITE FINISH)

# %%
# General rules -> no relations
rules = association_rules(frequent_itemsets, metric ="lift", min_threshold = 1)
rules
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %%
# Basket for France
basket_France = (df[df['Country'] =="France"]
          .groupby(['InvoiceNo', 'StockCode'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
basket_France = basket_France.applymap(encode_units)

# %%
frq_items = apriori(basket_France, min_support = 0.05, use_colnames = True)
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
rules.head()
# Out:
#         antecedents consequents  antecedent support  consequent support  \
# 1           (20712)      (POST)            0.076531            0.765306
# 240  (22554, 21731)      (POST)            0.053571            0.765306
# 246  (21731, 22556)      (POST)            0.051020            0.765306
# 209  (21080, 21086)     (21094)            0.102041            0.127551
# 208  (21080, 21094)     (21086)            0.102041            0.137755
#
#       support  confidence      lift  leverage  conviction
# 1    0.076531       1.000  1.306667  0.017961         inf
# 240  0.053571       1.000  1.306667  0.012573         inf
# 246  0.051020       1.000  1.306667  0.011974         inf
# 209  0.099490       0.975  7.644000  0.086474   34.897959
# 208  0.099490       0.975  7.077778  0.085433   34.489796

# %% [markdown]
# Support is the relative frequency that the rules show up. In many instances, you may want to look for high support in order to make sure it is a useful relationship. However, there may be instances where a low support is useful if you are trying to find “hidden” relationships.
#
# Confidence is a measure of the reliability of the rule. A confidence of .5 in the above example would mean that in 50% of the cases where Diaper and Gum were purchased, the purchase also included Beer and Chips. For product recommendation, a 50% confidence may be perfectly acceptable but in a medical situation, this level may not be high enough.
#
# Lift is the ratio of the observed support to that expected if the two rules were independent (see wikipedia). The basic rule of thumb is that a lift value close to 1 means the rules were completely independent. Lift values > 1 are generally more “interesting” and could be indicative of a useful rule pattern.

# %%
filter_rules = rules.loc[(rules['confidence']>0.5) & (rules['lift']>1.0)]
filter_rules.head()
# Out:
#         antecedents consequents  antecedent support  consequent support  \
# 1           (20712)      (POST)            0.076531            0.765306
# 240  (22554, 21731)      (POST)            0.053571            0.765306
# 246  (21731, 22556)      (POST)            0.051020            0.765306
# 209  (21080, 21086)     (21094)            0.102041            0.127551
# 208  (21080, 21094)     (21086)            0.102041            0.137755
#
#       support  confidence      lift  leverage  conviction
# 1    0.076531       1.000  1.306667  0.017961         inf
# 240  0.053571       1.000  1.306667  0.012573         inf
# 246  0.051020       1.000  1.306667  0.011974         inf
# 209  0.099490       0.975  7.644000  0.086474   34.897959
# 208  0.099490       0.975  7.077778  0.085433   34.489796

# %%
#France WH
coordinates = [[x,y] for x in range(40) for y in range(40)]
coordinates2 = [[x,y] for x in range(40) for y in range(40)]
x = [p[0] for p in coordinates]
y = [p[1] for p in coordinates]

# %%
# not used
distance0 = []
def manhattan(coord):
    for i in range(len(coord)):
        distance0.append(cityblock([0,0],[coord[i][0],coord[i][1]]))
manhattan(coordinates)

# %%
# not used
dic = {'x':x, 'y':y,'coordinates':coordinates, 'distance0':distance0}

# %%
wh = pd.DataFrame(dic).sort_values('distance0')
wh['rank'] = wh['distance0'].rank(method='first')
wh.reset_index(inplace=True, drop=True)
wh.head()
# Out:
#    x  y coordinates  distance0  rank
# 0  0  0      [0, 0]          0   1.0
# 1  0  1      [0, 1]          1   2.0
# 2  1  0      [1, 0]          1   3.0
# 3  0  2      [0, 2]          2   4.0
# 4  2  0      [2, 0]          2   5.0

# %%
# filter products France
products_fr = df[df['Country'] =="France"]
products_fr.head()
# Out:
#    InvoiceNo StockCode                      Description  Quantity  \
# 26    536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 27    536370     22727         ALARM CLOCK BAKELIKE RED        24
# 28    536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 29    536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 30    536370     21883                  STARS GIFT TAPE        24
#
#        InvoiceDate  UnitPrice  CustomerID Country
# 26  12/1/2010 8:45       3.75     12583.0  France
# 27  12/1/2010 8:45       3.75     12583.0  France
# 28  12/1/2010 8:45       3.75     12583.0  France
# 29  12/1/2010 8:45       0.85     12583.0  France
# 30  12/1/2010 8:45       0.65     12583.0  France

# %%
# French stock codes with support + rank
products = products_fr.groupby('StockCode').agg({'Quantity':'count'}).reset_index().sort_values('Quantity', ascending=False)
products['Support'] = products['Quantity']/sum(products['Quantity'])
products['Rank'] = products['Support'].rank(method='first',ascending=False)
products.reset_index(inplace=True, drop=True)
products.head()
# Out:
#   StockCode  Quantity   Support  Rank
# 0      POST       300  0.035680   1.0
# 1     23084        74  0.008801   2.0
# 2     21731        71  0.008444   3.0
# 3     22554        68  0.008088   4.0
# 4     22556        66  0.007850   5.0

# %%
# Randomly shuffel locations and adding random + location based on support
random.shuffle(coordinates2)
products['RandomLoc'] = coordinates2[0:int(len(products['StockCode']))]
products['SupportLoc'] = wh['coordinates'][0:int(len(products['StockCode']))+1]
filter_rules.reset_index(inplace=True, drop=True)

# %%
filter_rules
# Out:
#         antecedents    consequents  antecedent support  consequent support  \
# 0           (20712)         (POST)            0.076531            0.765306
# 1    (22554, 21731)         (POST)            0.053571            0.765306
# 2    (21731, 22556)         (POST)            0.051020            0.765306
# 3    (21080, 21086)        (21094)            0.102041            0.127551
# 4    (21080, 21094)        (21086)            0.102041            0.137755
# ..              ...            ...                 ...                 ...
# 197         (21559)        (22352)            0.122449            0.142857
# 198  (22554, 22551)  (POST, 22556)            0.104592            0.147959
# 199   (22352, POST)        (21559)            0.114796            0.122449
# 200   (21559, POST)        (22352)            0.114796            0.142857
# 201         (23206)        (22382)            0.125000            0.119898
#
#       support  confidence      lift  leverage  conviction
# 0    0.076531    1.000000  1.306667  0.017961         inf
# 1    0.053571    1.000000  1.306667  0.012573         inf
# 2    0.051020    1.000000  1.306667  0.011974         inf
# 3    0.099490    0.975000  7.644000  0.086474   34.897959
# 4    0.099490    0.975000  7.077778  0.085433   34.489796
# ..        ...         ...       ...       ...         ...
# 197  0.063776    0.520833  3.645833  0.046283    1.788820
# 198  0.053571    0.512195  3.461733  0.038096    1.746684
# 199  0.058673    0.511111  4.174074  0.044617    1.794991
# 200  0.058673    0.511111  3.577778  0.042274    1.753247
# 201  0.063776    0.510204  4.255319  0.048788    1.796875
#
# [202 rows x 9 columns]

# %%
products.head()
# Out:
#   StockCode  Quantity   Support  Rank RandomLoc SupportLoc
# 0      POST       300  0.035680   1.0  [28, 13]     [0, 0]
# 1     23084        74  0.008801   2.0  [26, 31]     [0, 1]
# 2     21731        71  0.008444   3.0  [39, 20]     [1, 0]
# 3     22554        68  0.008088   4.0   [3, 33]     [0, 2]
# 4     22556        66  0.007850   5.0  [33, 22]     [2, 0]

# %%
# Combine lists of pairs
ls_ant = []
for i in filter_rules['antecedents']:
    ls_ant.append(list(i))
    
ls_con = []
for i in filter_rules['consequents']:
    ls_con.append(list(i))
    
ls_comb = list(zip(ls_ant,ls_con))
ls_comb
# Out:
# [(['20712'], ['POST']),
#  (['22554', '21731'], ['POST']),
#  (['21731', '22556'], ['POST']),
#  (['21080', '21086'], ['21094']),
#  (['21080', '21094'], ['21086']),
#  (['21080', 'POST', '21086'], ['21094']),
#  (['21080', '21094', 'POST'], ['21086']),
#  (['21936'], ['POST']),
#  (['22437'], ['POST']),
#  (['21094'], ['21086']),
#  (['21987'], ['POST']),
#  (['22333'], ['POST']),
#  (['22467'], ['POST']),
#  (['21988'], ['POST']),
#  (['21094', 'POST'], ['21086']),
#  (['22961'], ['POST']),
#  (['84997D'], ['POST']),
#  (['22027'], ['POST']),
#  (['21559'], ['POST']),
#  (['22326'], ['POST']),
#  (['23203'], ['POST']),
#  (['23256'], ['23254']),
#  (['20749'], ['POST']),
#  (['22895'], ['POST']),
#  (['20725', '23206'], ['POST']),
#  (['22352', '21559'], ['POST']),
#  (['22328', '22326'], ['POST']),
#  (['22727'], ['POST']),
#  (['22728', 'POST', '22726'], ['22727']),
#  (['21988'], ['21987']),
#  (['22976'], ['POST']),
#  (['47566'], ['POST']),
#  (['20725', '20726'], ['POST']),
#  (['22727', '22726'], ['POST']),
#  (['20719'], ['POST']),
#  (['22727', '22728'], ['POST']),
#  (['23254'], ['23256']),
#  (['21086'], ['21094']),
#  (['22303'], ['POST']),
#  (['22661'], ['POST']),
#  (['23199'], ['POST']),
#  (['22328'], ['POST']),
#  (['22383'], ['POST']),
#  (['22385'], ['POST']),
#  (['22727', '22728', '22726'], ['POST']),
#  (['22556'], ['POST']),
#  (['23084'], ['POST']),
#  (['22090'], ['POST']),
#  (['22728'], ['POST']),
#  (['21731'], ['POST']),
#  (['POST', '21086'], ['21094']),
#  (['20726'], ['POST']),
#  (['22726'], ['POST']),
#  (['22728', '22726'], ['22727']),
#  (['22727', '22728'], ['22726']),
#  (['21086'], ['POST']),
#  (['POST', '22726'], ['22727']),
#  (['23209'], ['POST']),
#  (['22727', '22728', 'POST'], ['22726']),
#  (['22435'], ['POST']),
#  (['20724'], ['POST']),
#  (['85099B'], ['POST']),
#  (['21094'], ['POST']),
#  (['22382', '20726'], ['POST']),
#  (['22727'], ['22726']),
#  (['22423'], ['POST']),
#  (['23206'], ['POST']),
#  (['20750'], ['POST']),
#  (['22551'], ['POST']),
#  (['21121'], ['POST']),
#  (['21094', '21086'], ['POST']),
#  (['22556', '22551'], ['POST']),
#  (['22728', '22726'], ['POST']),
#  (['21080'], ['POST']),
#  (['21212'], ['POST']),
#  (['21080', '21086'], ['POST']),
#  (['21080', '21094'], ['POST']),
#  (['22554', '22556'], ['POST']),
#  (['22727', 'POST'], ['22726']),
#  (['21080', '21094', '21086'], ['POST']),
#  (['22726'], ['22727']),
#  (['21094', '21086'], ['21080']),
#  (['22367'], ['POST']),
#  (['22382', '20725'], ['POST']),
#  (['22727', '22726'], ['22728']),
#  (['22554'], ['POST']),
#  (['22554', '22551'], ['POST']),
#  (['22352'], ['POST']),
#  (['21987'], ['21988']),
#  (['21094'], ['POST', '21086']),
#  (['21094'], ['21080']),
#  (['22382', '23206'], ['POST']),
#  (['21080', '21086'], ['21094', 'POST']),
#  (['21080', '21094'], ['POST', '21086']),
#  (['21094', 'POST', '21086'], ['21080']),
#  (['20725'], ['POST']),
#  (['22727', 'POST', '22726'], ['22728']),
#  (['22029'], ['POST']),
#  (['22620'], ['POST']),
#  (['21094', 'POST'], ['21080']),
#  (['22727'], ['22728']),
#  (['22555'], ['POST']),
#  (['22492'], ['POST']),
#  (['21094'], ['21080', '21086']),
#  (['22631'], ['POST']),
#  (['22659'], ['POST']),
#  (['23204'], ['POST']),
#  (['22556', '22554', '22551'], ['POST']),
#  (['22629'], ['POST']),
#  (['22556', '22551'], ['22554']),
#  (['21080'], ['21094']),
#  (['21080'], ['21086']),
#  (['21080', 'POST'], ['21094']),
#  (['21080', 'POST'], ['21086']),
#  (['22382'], ['POST']),
#  (['22727', 'POST'], ['22728']),
#  (['22726'], ['22728']),
#  (['21094', 'POST'], ['21080', '21086']),
#  (['22551'], ['22554']),
#  (['22727', '22728'], ['POST', '22726']),
#  (['22728', '22726'], ['22727', 'POST']),
#  (['22727'], ['POST', '22726']),
#  (['21080'], ['21094', '21086']),
#  (['21080', 'POST'], ['21094', '21086']),
#  (['22728', 'POST'], ['22727']),
#  (['21086'], ['21094', 'POST']),
#  (['21086'], ['21080']),
#  (['22726'], ['22727', 'POST']),
#  (['POST', '22551'], ['22554']),
#  (['POST', '22726'], ['22728']),
#  (['22728'], ['22727']),
#  (['22728'], ['22726']),
#  (['POST', '22630'], ['22629']),
#  (['22556', 'POST', '22551'], ['22554']),
#  (['21086'], ['21080', '21094']),
#  (['22555'], ['22556']),
#  (['22630'], ['22629']),
#  (['POST', '21086'], ['21080']),
#  (['22727', '22726'], ['22728', 'POST']),
#  (['22727'], ['22728', 'POST']),
#  (['POST', '21086'], ['21080', '21094']),
#  (['22728', 'POST'], ['22726']),
#  (['22727'], ['22728', '22726']),
#  (['22554', '22556'], ['22551']),
#  (['POST', '22726'], ['22727', '22728']),
#  (['21094', '21086'], ['21080', 'POST']),
#  (['21094'], ['21080', 'POST']),
#  (['22554', '22551'], ['22556']),
#  (['22726'], ['22727', '22728']),
#  (['22728'], ['22727', 'POST']),
#  (['22551'], ['22556']),
#  (['22727', 'POST'], ['22728', '22726']),
#  (['POST', '22551'], ['22556']),
#  (['21094'], ['21080', 'POST', '21086']),
#  (['POST', '22554', '22556'], ['22551']),
#  (['POST', '22554', '22551'], ['22556']),
#  (['21080'], ['21094', 'POST']),
#  (['21080'], ['POST', '21086']),
#  (['22726'], ['22728', 'POST']),
#  (['22728', 'POST'], ['22727', '22726']),
#  (['22728'], ['22727', '22726']),
#  (['POST', '22328'], ['22326']),
#  (['21080'], ['21094', 'POST', '21086']),
#  (['22554'], ['22551']),
#  (['21086'], ['21080', 'POST']),
#  (['POST', '22554'], ['22551']),
#  (['22551'], ['POST', '22554']),
#  (['POST', '22554'], ['22556']),
#  (['22662'], ['22382']),
#  (['22556'], ['22554']),
#  (['22728'], ['POST', '22726']),
#  (['22556', '22551'], ['POST', '22554']),
#  (['22554'], ['22556']),
#  (['22328'], ['22326']),
#  (['22727'], ['22728', 'POST', '22726']),
#  (['21086'], ['21080', '21094', 'POST']),
#  (['POST', '23206'], ['20725']),
#  (['22382', 'POST'], ['20726']),
#  (['22382', 'POST'], ['20725']),
#  (['22726'], ['22727', '22728', 'POST']),
#  (['22629'], ['22630']),
#  (['POST', '22556'], ['22554']),
#  (['22382', 'POST'], ['23206']),
#  (['22382'], ['20725']),
#  (['POST', '22629'], ['22630']),
#  (['22728'], ['22727', 'POST', '22726']),
#  (['22328'], ['POST', '22326']),
#  (['20726'], ['22382']),
#  (['22727'], ['22326']),
#  (['22630'], ['POST', '22629']),
#  (['22551'], ['POST', '22556']),
#  (['22382'], ['20726']),
#  (['22382'], ['23206']),
#  (['23206'], ['20725']),
#  (['22556'], ['22551']),
#  (['22554', '22556'], ['POST', '22551']),
#  (['20726', 'POST'], ['22382']),
#  (['21559'], ['22352']),
#  (['22554', '22551'], ['POST', '22556']),
#  (['22352', 'POST'], ['21559']),
#  (['21559', 'POST'], ['22352']),
#  (['23206'], ['22382'])]

# %%
# combine into one list + unique list + unique flat list
ls_comb2 = []
for i in range(len(ls_comb)):
    ls_comb2.append(sorted(ls_comb[i][0]+ls_comb[i][1]))
    
ls_sup = []
for i in filter_rules['support']:
    ls_sup.append(i)

ls_unique = []
for i in ls_comb2:
    if i not in ls_unique:
        ls_unique.append(i)
        
flat_list = set([item for sublist in ls_unique for item in sublist])

# %%
# Test
ls4 = []
for i, j in zip(ls_comb2, ls_sup):
    for k in ls_unique:
        if k == i:
            if [k,j] not in ls4:
                ls4.append([k,j])

# %%
# Test
merged = products[['StockCode','Support']].append(df_basket, ignore_index=True).sort_values('Support',ascending=False)
merged.head(80)
# Out:
#                  StockCode   Support
# 1583         [23084, POST]  0.165816
# 1586         [21731, POST]  0.158163
# 1559         [22326, POST]  0.147959
# 1582         [22556, POST]  0.147959
# 1612         [22554, POST]  0.137755
# ...                    ...       ...
# 1551         [22333, POST]  0.058673
# 1565  [21559, 22352, POST]  0.058673
# 1619         [22620, POST]  0.056122
# 1592         [22435, POST]  0.056122
# 1618         [22029, POST]  0.056122
#
# [80 rows x 2 columns]

# %%
# Test
ls5 = []
for i, j in ls4:
    for k in range(len(i)):
        ls5.append([i[k],j])

# %%
# Test
ls_sup2 = []
for i, j in zip(ls_comb2,ls_sup):
    for k in ls_unique:
        if i == k:
            ls_sup2.append([i, j])

# %%
# Test
ls3 = []
for i, j in sorted(zip(ls_sup,ls_comb2),reverse=True):
    ls3.append([i,j])

# %%
# Test
ls3_unique = []
for i in ls3:
    if i not in ls3_unique:
        ls3_unique.append(i)

# %%
# not used anymore I think
unique_sku = []
for i in range(len(ls_unique)):
    for j in ls_unique[i]:
        unique_sku.append(int(products[products['StockCode'] == j]['Quantity']))

# %%
# Full dict
dic_un = []
for i in ls_unique:
    dic_un.append({
        'combo':i
    })
for i in range(len(dic_un)):
    dic_un[i]['sku'] = [int(products[products['StockCode'] == j]['Quantity']) for j in dic_un[i]['combo']]
    dic_un[i]['avg_sku'] = int(np.mean(dic_un[i]['sku']))

# %%
dic_un
# Out:
# [{'combo': ['20712', 'POST'], 'sku': [30, 300], 'avg_sku': 165},
#  {'combo': ['21731', '22554', 'POST'], 'sku': [71, 68, 300], 'avg_sku': 146},
#  {'combo': ['21731', '22556', 'POST'], 'sku': [71, 66, 300], 'avg_sku': 145},
#  {'combo': ['21080', '21086', '21094'], 'sku': [52, 54, 50], 'avg_sku': 52},
#  {'combo': ['21080', '21086', '21094', 'POST'],
#   'sku': [52, 54, 50, 300],
#   'avg_sku': 114},
#  {'combo': ['21936', 'POST'], 'sku': [28, 300], 'avg_sku': 164},
#  {'combo': ['22437', 'POST'], 'sku': [26, 300], 'avg_sku': 163},
#  {'combo': ['21086', '21094'], 'sku': [54, 50], 'avg_sku': 52},
#  {'combo': ['21987', 'POST'], 'sku': [25, 300], 'avg_sku': 162},
#  {'combo': ['22333', 'POST'], 'sku': [24, 300], 'avg_sku': 162},
#  {'combo': ['22467', 'POST'], 'sku': [23, 300], 'avg_sku': 161},
#  {'combo': ['21988', 'POST'], 'sku': [22, 300], 'avg_sku': 161},
#  {'combo': ['21086', '21094', 'POST'], 'sku': [54, 50, 300], 'avg_sku': 134},
#  {'combo': ['22961', 'POST'], 'sku': [21, 300], 'avg_sku': 160},
#  {'combo': ['84997D', 'POST'], 'sku': [21, 300], 'avg_sku': 160},
#  {'combo': ['22027', 'POST'], 'sku': [37, 300], 'avg_sku': 168},
#  {'combo': ['21559', 'POST'], 'sku': [48, 300], 'avg_sku': 174},
#  {'combo': ['22326', 'POST'], 'sku': [62, 300], 'avg_sku': 181},
#  {'combo': ['23203', 'POST'], 'sku': [29, 300], 'avg_sku': 164},
#  {'combo': ['23254', '23256'], 'sku': [28, 27], 'avg_sku': 27},
#  {'combo': ['20749', 'POST'], 'sku': [27, 300], 'avg_sku': 163},
#  {'combo': ['22895', 'POST'], 'sku': [28, 300], 'avg_sku': 164},
#  {'combo': ['20725', '23206', 'POST'], 'sku': [60, 50, 300], 'avg_sku': 136},
#  {'combo': ['21559', '22352', 'POST'], 'sku': [48, 56, 300], 'avg_sku': 134},
#  {'combo': ['22326', '22328', 'POST'], 'sku': [62, 43, 300], 'avg_sku': 135},
#  {'combo': ['22727', 'POST'], 'sku': [37, 300], 'avg_sku': 168},
#  {'combo': ['22726', '22727', '22728', 'POST'],
#   'sku': [38, 37, 40, 300],
#   'avg_sku': 103},
#  {'combo': ['21987', '21988'], 'sku': [25, 22], 'avg_sku': 23},
#  {'combo': ['22976', 'POST'], 'sku': [23, 300], 'avg_sku': 161},
#  {'combo': ['47566', 'POST'], 'sku': [22, 300], 'avg_sku': 161},
#  {'combo': ['20725', '20726', 'POST'], 'sku': [60, 46, 300], 'avg_sku': 135},
#  {'combo': ['22726', '22727', 'POST'], 'sku': [38, 37, 300], 'avg_sku': 125},
#  {'combo': ['20719', 'POST'], 'sku': [29, 300], 'avg_sku': 164},
#  {'combo': ['22727', '22728', 'POST'], 'sku': [37, 40, 300], 'avg_sku': 125},
#  {'combo': ['22303', 'POST'], 'sku': [27, 300], 'avg_sku': 163},
#  {'combo': ['22661', 'POST'], 'sku': [26, 300], 'avg_sku': 163},
#  {'combo': ['23199', 'POST'], 'sku': [26, 300], 'avg_sku': 163},
#  {'combo': ['22328', 'POST'], 'sku': [43, 300], 'avg_sku': 171},
#  {'combo': ['22383', 'POST'], 'sku': [26, 300], 'avg_sku': 163},
#  {'combo': ['22385', 'POST'], 'sku': [25, 300], 'avg_sku': 162},
#  {'combo': ['22556', 'POST'], 'sku': [66, 300], 'avg_sku': 183},
#  {'combo': ['23084', 'POST'], 'sku': [74, 300], 'avg_sku': 187},
#  {'combo': ['22090', 'POST'], 'sku': [32, 300], 'avg_sku': 166},
#  {'combo': ['22728', 'POST'], 'sku': [40, 300], 'avg_sku': 170},
#  {'combo': ['21731', 'POST'], 'sku': [71, 300], 'avg_sku': 185},
#  {'combo': ['20726', 'POST'], 'sku': [46, 300], 'avg_sku': 173},
#  {'combo': ['22726', 'POST'], 'sku': [38, 300], 'avg_sku': 169},
#  {'combo': ['22726', '22727', '22728'], 'sku': [38, 37, 40], 'avg_sku': 38},
#  {'combo': ['21086', 'POST'], 'sku': [54, 300], 'avg_sku': 177},
#  {'combo': ['23209', 'POST'], 'sku': [33, 300], 'avg_sku': 166},
#  {'combo': ['22435', 'POST'], 'sku': [26, 300], 'avg_sku': 163},
#  {'combo': ['20724', 'POST'], 'sku': [38, 300], 'avg_sku': 169},
#  {'combo': ['85099B', 'POST'], 'sku': [39, 300], 'avg_sku': 169},
#  {'combo': ['21094', 'POST'], 'sku': [50, 300], 'avg_sku': 175},
#  {'combo': ['20726', '22382', 'POST'], 'sku': [46, 47, 300], 'avg_sku': 131},
#  {'combo': ['22726', '22727'], 'sku': [38, 37], 'avg_sku': 37},
#  {'combo': ['22423', 'POST'], 'sku': [49, 300], 'avg_sku': 174},
#  {'combo': ['23206', 'POST'], 'sku': [50, 300], 'avg_sku': 175},
#  {'combo': ['20750', 'POST'], 'sku': [54, 300], 'avg_sku': 177},
#  {'combo': ['22551', 'POST'], 'sku': [54, 300], 'avg_sku': 177},
#  {'combo': ['21121', 'POST'], 'sku': [30, 300], 'avg_sku': 165},
#  {'combo': ['22551', '22556', 'POST'], 'sku': [54, 66, 300], 'avg_sku': 140},
#  {'combo': ['22726', '22728', 'POST'], 'sku': [38, 40, 300], 'avg_sku': 126},
#  {'combo': ['21080', 'POST'], 'sku': [52, 300], 'avg_sku': 176},
#  {'combo': ['21212', 'POST'], 'sku': [40, 300], 'avg_sku': 170},
#  {'combo': ['21080', '21086', 'POST'], 'sku': [52, 54, 300], 'avg_sku': 135},
#  {'combo': ['21080', '21094', 'POST'], 'sku': [52, 50, 300], 'avg_sku': 134},
#  {'combo': ['22554', '22556', 'POST'], 'sku': [68, 66, 300], 'avg_sku': 144},
#  {'combo': ['22367', 'POST'], 'sku': [26, 300], 'avg_sku': 163},
#  {'combo': ['20725', '22382', 'POST'], 'sku': [60, 47, 300], 'avg_sku': 135},
#  {'combo': ['22554', 'POST'], 'sku': [68, 300], 'avg_sku': 184},
#  {'combo': ['22551', '22554', 'POST'], 'sku': [54, 68, 300], 'avg_sku': 140},
#  {'combo': ['22352', 'POST'], 'sku': [56, 300], 'avg_sku': 178},
#  {'combo': ['21080', '21094'], 'sku': [52, 50], 'avg_sku': 51},
#  {'combo': ['22382', '23206', 'POST'], 'sku': [47, 50, 300], 'avg_sku': 132},
#  {'combo': ['20725', 'POST'], 'sku': [60, 300], 'avg_sku': 180},
#  {'combo': ['22029', 'POST'], 'sku': [28, 300], 'avg_sku': 164},
#  {'combo': ['22620', 'POST'], 'sku': [28, 300], 'avg_sku': 164},
#  {'combo': ['22727', '22728'], 'sku': [37, 40], 'avg_sku': 38},
#  {'combo': ['22555', 'POST'], 'sku': [32, 300], 'avg_sku': 166},
#  {'combo': ['22492', 'POST'], 'sku': [41, 300], 'avg_sku': 170},
#  {'combo': ['22631', 'POST'], 'sku': [27, 300], 'avg_sku': 163},
#  {'combo': ['22659', 'POST'], 'sku': [27, 300], 'avg_sku': 163},
#  {'combo': ['23204', 'POST'], 'sku': [27, 300], 'avg_sku': 163},
#  {'combo': ['22551', '22554', '22556', 'POST'],
#   'sku': [54, 68, 66, 300],
#   'avg_sku': 122},
#  {'combo': ['22629', 'POST'], 'sku': [50, 300], 'avg_sku': 175},
#  {'combo': ['22551', '22554', '22556'], 'sku': [54, 68, 66], 'avg_sku': 62},
#  {'combo': ['21080', '21086'], 'sku': [52, 54], 'avg_sku': 53},
#  {'combo': ['22382', 'POST'], 'sku': [47, 300], 'avg_sku': 173},
#  {'combo': ['22726', '22728'], 'sku': [38, 40], 'avg_sku': 39},
#  {'combo': ['22551', '22554'], 'sku': [54, 68], 'avg_sku': 61},
#  {'combo': ['22629', '22630', 'POST'], 'sku': [50, 39, 300], 'avg_sku': 129},
#  {'combo': ['22555', '22556'], 'sku': [32, 66], 'avg_sku': 49},
#  {'combo': ['22629', '22630'], 'sku': [50, 39], 'avg_sku': 44},
#  {'combo': ['22551', '22556'], 'sku': [54, 66], 'avg_sku': 60},
#  {'combo': ['22382', '22662'], 'sku': [47, 33], 'avg_sku': 40},
#  {'combo': ['22554', '22556'], 'sku': [68, 66], 'avg_sku': 67},
#  {'combo': ['22326', '22328'], 'sku': [62, 43], 'avg_sku': 52},
#  {'combo': ['20725', '22382'], 'sku': [60, 47], 'avg_sku': 53},
#  {'combo': ['20726', '22382'], 'sku': [46, 47], 'avg_sku': 46},
#  {'combo': ['22326', '22727'], 'sku': [62, 37], 'avg_sku': 49},
#  {'combo': ['22382', '23206'], 'sku': [47, 50], 'avg_sku': 48},
#  {'combo': ['20725', '23206'], 'sku': [60, 50], 'avg_sku': 55},
#  {'combo': ['21559', '22352'], 'sku': [48, 56], 'avg_sku': 52}]

# %%
flat_list = set([item for sublist in ls_unique for item in sublist])

# %%
#list for pair or not pair
flat = []
for i in products['StockCode']:
    if i in flat_list:
        flat.append(1)
    else:
        flat.append(0)
products.head(70)
# Out:
#    StockCode  Quantity   Support  Rank RandomLoc SupportLoc
# 0       POST       300  0.035680   1.0  [28, 13]     [0, 0]
# 1      23084        74  0.008801   2.0  [26, 31]     [0, 1]
# 2      21731        71  0.008444   3.0  [39, 20]     [1, 0]
# 3      22554        68  0.008088   4.0   [3, 33]     [0, 2]
# 4      22556        66  0.007850   5.0  [33, 22]     [2, 0]
# ..       ...       ...       ...   ...       ...        ...
# 65     22467        23  0.002735  66.0  [11, 31]     [9, 1]
# 66     22976        23  0.002735  67.0  [11, 20]    [0, 11]
# 67     21156        22  0.002617  68.0   [37, 0]     [7, 4]
# 68     22992        22  0.002617  69.0   [17, 7]    [10, 1]
# 69     21988        22  0.002617  70.0  [13, 34]    [11, 0]
#
# [70 rows x 6 columns]

# %%
# Add check + sort DF
products['Check'] = flat
products.sort_values(['Check','Quantity'],ascending=False,inplace=True)
products.reset_index(inplace=True, drop=True)
products.head()
# Out:
#   StockCode  Quantity   Support  Rank RandomLoc SupportLoc  Check
# 0      POST       300  0.035680   1.0  [28, 13]     [0, 0]      1
# 1     23084        74  0.008801   2.0  [26, 31]     [0, 1]      1
# 2     21731        71  0.008444   3.0  [39, 20]     [1, 0]      1
# 3     22554        68  0.008088   4.0   [3, 33]     [0, 2]      1
# 4     22556        66  0.007850   5.0  [33, 22]     [2, 0]      1

# %%
products['BasketLoc'] = wh['coordinates'][0:int(len(products['StockCode']))+1]

# %%
products.head(65)
# Out:
#    StockCode  Quantity   Support  Rank RandomLoc SupportLoc  Check BasketLoc
# 0       POST       300  0.035680   1.0  [28, 13]     [0, 0]      1    [0, 0]
# 1      23084        74  0.008801   2.0  [26, 31]     [0, 1]      1    [0, 1]
# 2      21731        71  0.008444   3.0  [39, 20]     [1, 0]      1    [1, 0]
# 3      22554        68  0.008088   4.0   [3, 33]     [0, 2]      1    [0, 2]
# 4      22556        66  0.007850   5.0  [33, 22]     [2, 0]      1    [2, 0]
# ..       ...       ...       ...   ...       ...        ...    ...       ...
# 60     47566        22  0.002617  71.0  [34, 23]     [4, 7]      1    [5, 5]
# 61    84997D        21  0.002498  73.0  [27, 36]     [2, 9]      1    [8, 2]
# 62     22961        21  0.002498  74.0    [2, 1]     [6, 5]      1   [10, 0]
# 63     22139        34  0.004044  30.0  [11, 38]     [1, 6]      0    [2, 8]
# 64     22138        32  0.003806  33.0   [1, 19]     [3, 4]      0   [0, 10]
#
# [65 rows x 8 columns]

# %%
cityblock([0,0],[1,6]),cityblock([0,0],[2,8])
# Out:
# (7, 10)

# %%
#Merge tables
merge_prod = products[['StockCode','RandomLoc','SupportLoc','BasketLoc','Check']]
merge_fr = products_fr.merge(merge_prod, on='StockCode', how='left')
merge_fr.head()
# Out:
#   InvoiceNo StockCode                      Description  Quantity  \
# 0    536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 1    536370     22727         ALARM CLOCK BAKELIKE RED        24
# 2    536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 3    536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 4    536370     21883                  STARS GIFT TAPE        24
#
#       InvoiceDate  UnitPrice  CustomerID Country RandomLoc SupportLoc  \
# 0  12/1/2010 8:45       3.75     12583.0  France  [30, 11]     [1, 5]
# 1  12/1/2010 8:45       3.75     12583.0  France    [8, 3]     [6, 1]
# 2  12/1/2010 8:45       3.75     12583.0  France  [18, 18]     [5, 1]
# 3  12/1/2010 8:45       0.85     12583.0  France  [14, 11]   [14, 23]
# 4  12/1/2010 8:45       0.65     12583.0  France  [28, 25]    [10, 5]
#
#   BasketLoc  Check
# 0    [1, 5]      1
# 1    [6, 1]      1
# 2    [5, 1]      1
# 3  [14, 23]      0
# 4   [10, 5]      0

# %%
# Merge distance to 0
merge_fr['Random0'] = merge_fr['RandomLoc'].apply(lambda x: cityblock([0,0],x))
merge_fr['Support0'] = merge_fr['SupportLoc'].apply(lambda x: cityblock([0,0],x))
merge_fr['Basket0'] = merge_fr['BasketLoc'].apply(lambda x: cityblock([0,0],x))

# %%
# %%time
# Creating dictionary
dic = []
for i in merge_fr['InvoiceNo'].unique():
    dic.append({
        'id' : i,
        'code' : [i for i in merge_fr[merge_fr['InvoiceNo']==i]['StockCode']],
        'sku' : [i for i in merge_fr[merge_fr['InvoiceNo']==i]['Quantity']],
        'random_coo' : [i for i in merge_fr[merge_fr['InvoiceNo']==i]['RandomLoc']],
        'support_coo' : [i for i in merge_fr[merge_fr['InvoiceNo']==i]['SupportLoc']],
        'basket_coo' : [i for i in merge_fr[merge_fr['InvoiceNo']==i]['BasketLoc']],
        })
# Out:
# CPU times: user 2.56 s, sys: 29.6 ms, total: 2.59 s
# Wall time: 2.9 s

# %%
# Distance to 0 to order route
for i in range(len(dic)):
    dic[i]['random0'] = [cityblock([0,0],i) for i in dic[i]['random_coo']]
    dic[i]['support0'] = [cityblock([0,0],i) for i in dic[i]['support_coo']]
    dic[i]['basket0'] = [cityblock([0,0],i) for i in dic[i]['basket_coo']]

# %%
# Sort locations + remove distance0
for i in range(len(dic)):
    dic[i]['random_coo'] = [0,0] + [i for i, j 
                            in sorted(zip(dic[i]['random_coo'],dic[i]['random0']), key = lambda t: t[1])] + [0,0]
    dic[i]['support_coo'] = [0,0] + [i for i, j 
                            in sorted(zip(dic[i]['support_coo'],dic[i]['support0']), key = lambda t: t[1])] + [0,0]
    dic[i]['basket_coo'] = [0,0] + [i for i, j 
                            in sorted(zip(dic[i]['basket_coo'],dic[i]['basket0']), key = lambda t: t[1])] + [0,0]
    del(dic[i]['random0'])
    del(dic[i]['support0'])
    del(dic[i]['basket0'])

# %%
dic[1]
# Out:
# {'id': '536852',
#  'code': ['22549', '22544', '22539', '22661', '21791', '21786', 'POST'],
#  'sku': [12, 24, 24, 10, 12, 24, 1],
#  'random_coo': [0,
#   0,
#   [14, 6],
#   [29, 12],
#   [28, 13],
#   [3, 39],
#   [35, 15],
#   [20, 34],
#   [27, 29],
#   0,
#   0],
#  'support_coo': [0,
#   0,
#   [0, 0],
#   [6, 3],
#   [3, 12],
#   [11, 7],
#   [5, 15],
#   [10, 11],
#   [22, 9],
#   0,
#   0],
#  'basket_coo': [0,
#   0,
#   [0, 0],
#   [2, 7],
#   [3, 12],
#   [11, 7],
#   [5, 15],
#   [10, 11],
#   [22, 9],
#   0,
#   0]}

# %%
# Create distance steps
options = ['random_coo','support_coo','basket_coo']
for case in options:
    for i in range(len(dic)):
        for j in dic[i][case]:
            dic[i][f'{case}_steps'] = [cityblock(dic[i][case][j],dic[i][case][j+1]) 
                                                for j in range(len(dic[i][case])-1)]

# %%
dic[1]
# Out:
# {'id': '536852',
#  'code': ['22549', '22544', '22539', '22661', '21791', '21786', 'POST'],
#  'sku': [12, 24, 24, 10, 12, 24, 1],
#  'random_coo': [0,
#   0,
#   [14, 6],
#   [29, 12],
#   [28, 13],
#   [3, 39],
#   [35, 15],
#   [20, 34],
#   [27, 29],
#   0,
#   0],
#  'support_coo': [0,
#   0,
#   [0, 0],
#   [6, 3],
#   [3, 12],
#   [11, 7],
#   [5, 15],
#   [10, 11],
#   [22, 9],
#   0,
#   0],
#  'basket_coo': [0,
#   0,
#   [0, 0],
#   [2, 7],
#   [3, 12],
#   [11, 7],
#   [5, 15],
#   [10, 11],
#   [22, 9],
#   0,
#   0],
#  'random_coo_steps': [0, 20, 21, 2, 51, 56, 34, 12, 56, 0],
#  'support_coo_steps': [0, 0, 9, 12, 13, 14, 9, 14, 31, 0],
#  'basket_coo_steps': [0, 0, 9, 6, 13, 14, 9, 14, 31, 0]}

# %%
# Create total distance per order
options = ['random_coo','support_coo','basket_coo']
for case in options:
    for i in range(len(dic)):
        for j in dic[i][case]:
            dic[i][f'{case}_distance'] = sum(dic[i][f'{case}_steps'])

# %%
dic[1]
# Out:
# {'id': '536852',
#  'code': ['22549', '22544', '22539', '22661', '21791', '21786', 'POST'],
#  'sku': [12, 24, 24, 10, 12, 24, 1],
#  'random_coo': [0,
#   0,
#   [14, 6],
#   [29, 12],
#   [28, 13],
#   [3, 39],
#   [35, 15],
#   [20, 34],
#   [27, 29],
#   0,
#   0],
#  'support_coo': [0,
#   0,
#   [0, 0],
#   [6, 3],
#   [3, 12],
#   [11, 7],
#   [5, 15],
#   [10, 11],
#   [22, 9],
#   0,
#   0],
#  'basket_coo': [0,
#   0,
#   [0, 0],
#   [2, 7],
#   [3, 12],
#   [11, 7],
#   [5, 15],
#   [10, 11],
#   [22, 9],
#   0,
#   0],
#  'random_coo_steps': [0, 20, 21, 2, 51, 56, 34, 12, 56, 0],
#  'support_coo_steps': [0, 0, 9, 12, 13, 14, 9, 14, 31, 0],
#  'basket_coo_steps': [0, 0, 9, 6, 13, 14, 9, 14, 31, 0],
#  'random_coo_distance': 252,
#  'support_coo_distance': 102,
#  'basket_coo_distance': 96}

# %%
#Get distance
ls_random = []
ls_support = []
ls_basket = []
for i in range(len(dic)):
    ls_random.append(dic[i]['random_coo_distance'])
    ls_support.append(dic[i]['support_coo_distance'])
    ls_basket.append(dic[i]['basket_coo_distance'])

# %%
#total distance per method
sum(ls_random), sum(ls_support), sum(ls_basket)
# Out:
# (179298, 121206, 121594)

# %%
#Percentage changes methods
sum(ls_support)/sum(ls_random) - 1, sum(ls_basket)/sum(ls_support) - 1
# Out:
# (-0.3239969213265067, 0.003201161658663798)

# %%
merge_fr.head()
# Out:
#   InvoiceNo StockCode                      Description  Quantity  \
# 0    536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 1    536370     22727         ALARM CLOCK BAKELIKE RED        24
# 2    536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 3    536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 4    536370     21883                  STARS GIFT TAPE        24
#
#       InvoiceDate  UnitPrice  CustomerID Country RandomLoc SupportLoc  \
# 0  12/1/2010 8:45       3.75     12583.0  France  [30, 11]     [1, 5]
# 1  12/1/2010 8:45       3.75     12583.0  France    [8, 3]     [6, 1]
# 2  12/1/2010 8:45       3.75     12583.0  France  [18, 18]     [5, 1]
# 3  12/1/2010 8:45       0.85     12583.0  France  [14, 11]   [14, 23]
# 4  12/1/2010 8:45       0.65     12583.0  France  [28, 25]    [10, 5]
#
#   BasketLoc  Random0  Support0  Basket0
# 0    [1, 5]       41         6        6
# 1    [6, 1]       11         7        7
# 2    [5, 1]       36         6        6
# 3  [14, 23]       25        37       37
# 4   [10, 5]       53        15       15

# %%
#Viz
merge_viz = merge_fr[['RandomLoc', 'SupportLoc', 'BasketLoc', 'Quantity','Check']]
wh_viz = wh[['x','y','coordinates']]

# %%
merge_viz['RandomLoc'] = merge_viz['RandomLoc'].apply(tuple)
merge_viz['SupportLoc'] = merge_viz['SupportLoc'].apply(tuple)
merge_viz['BasketLoc'] = merge_viz['BasketLoc'].apply(tuple)
wh_viz['coordinates'] = wh_viz['coordinates'].apply(tuple)
# Out:
# /Users/admin/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/admin/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/admin/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/admin/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
wh_random = merge_viz.groupby(['RandomLoc','Check'])['Quantity'].count().reset_index().rename(columns={'RandomLoc':'coordinates'})
wh_support = merge_viz.groupby(['SupportLoc','Check'])['Quantity'].count().reset_index().rename(columns={'SupportLoc':'coordinates'})
wh_basket = merge_viz.groupby(['BasketLoc','Check'])['Quantity'].count().reset_index().rename(columns={'BasketLoc':'coordinates'})

# %%
wh_random = wh_random.merge(wh_viz, on='coordinates', how='left')
wh_support= wh_support.merge(wh_viz, on='coordinates', how='left')
wh_basket = wh_basket.merge(wh_viz, on='coordinates', how='left')

# %%
wh_random.head()
# Out:
#   coordinates  Check  Quantity  x  y
# 0      (0, 0)      0         1  0  0
# 1      (0, 1)      0        17  0  1
# 2      (0, 2)      0         1  0  2
# 3      (0, 3)      0         2  0  3
# 4      (0, 4)      0        11  0  4

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(data=wh_random, x='x', y='y', hue='Quantity', style='Check')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(data=wh_support, x='x', y='y', hue='Quantity', style='Check')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(data=wh_basket, x='x', y='y', hue='Quantity', style='Check')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>
