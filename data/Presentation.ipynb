# %% [markdown]
# ## A Priori Algorithm

# %% [markdown]
# Data mining techinque which uncovers meaningful correlations between different entities according to their co-occurrence in a data set.

# %% [markdown]
# ### Three major components of algorithm:
# > - Support
# > - Lift
# > - Confidence

# %% [markdown]
# <h4 align="center">Support</h4>
# <hr>
# <div style="text-align: center"> default popularity of an item based on it's frequency and the total amount of transactions</div>
#
#
# > $$ Support(X) = \frac{Frequency(X)}{N (total transactions)} $$

# %% [markdown]
# > $$ Support(X > Y) = \frac{Frequency(X \cap Y)}{N (totaltransactions)} $$

# %% [markdown]
# <h5 align="center">Example</h5>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Confidence

# %% [markdown]
# <h3 align="center">This is a centered header</h3>

# %% [markdown]
# <div style="text-align: center"> your-text-here </div>
