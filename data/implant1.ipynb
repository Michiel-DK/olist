# %%
import pandas as pd

# %%
orders = pd.read_csv('olist_orders_dataset.csv')

# %%
items = pd.read_csv('olist_order_items_dataset.csv')

# %%
products = pd.read_csv('olist_products_dataset.csv')

# %%
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
productitem = products.merge(items, on='product_id', how='left')

# %%
productitem.sort_values('product_category_name')
# Out:
#                               product_id      product_category_name  \
# 80391   66e94c5c07d64d44c16cd6903a79a453  agro_industria_e_comercio
# 88793   6ff1fc9209c7854704a4f75c9fac41b4  agro_industria_e_comercio
# 88792   6ff1fc9209c7854704a4f75c9fac41b4  agro_industria_e_comercio
# 88791   6ff1fc9209c7854704a4f75c9fac41b4  agro_industria_e_comercio
# 88790   6ff1fc9209c7854704a4f75c9fac41b4  agro_industria_e_comercio
# ...                                  ...                        ...
# 111596  10dbe0fbaa2c505123c17fdc34a63c56                        NaN
# 111633  bd2ada37b58ae94cc838b9c0569fecd8                        NaN
# 112027  fa51e914046aab32764c41356b9d4ea4                        NaN
# 112028  fa51e914046aab32764c41356b9d4ea4                        NaN
# 112324  c4ceee876c82b8328e9c293fa0e1989b                        NaN
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# ...

# %%
productitem.groupby('product_category_name').nunique()
# Out:
#                            product_id  product_name_lenght  \
# product_category_name
# agro_industria_e_comercio          74                   25
# alimentos                          82                   34
# alimentos_bebidas                 104                   39
# artes                              55                   27
# artes_e_artesanato                 19                   15
# ...                               ...                  ...
# sinalizacao_e_seguranca            93                   33
# tablets_impressao_imagem            9                    7
# telefonia                        1134                   48
# telefonia_fixa                    116                   37
# utilidades_domesticas            2335                   55
#
#                            product_description_lenght  product_photos_qty  \
# product_category_name
# agro_industria_e_comercio                          70                   8
# ...

# %%
orderprod = pd.pivot_table(productitem, index='product_id', values='order_id')
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-22-532ded5a9c0a> in <module>
# ----> 1 orderprod = pd.pivot_table(productitem, index='product_id', values='order_id')
#
# ~/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#     111
#     112     grouped = data.groupby(keys, observed=observed)
# --> 113     agged = grouped.agg(aggfunc)
#     114     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#     115         agged = agged.dropna(how="all")
#
# ~/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     943         func = maybe_mangle_lambdas(func)
#     944
# ...

# %%
orderprod
# Out:
#                                   product_id
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214           1
# 00018f77f2f0320c557190d7a144bdd3           1
# 000229ec398224ef6ca0657da4fc703e           1
# 00024acbcdf0a6daa1e931b038114c75           1
# 00042b26cf59d7ce69dfabb4e55b4fd9           1
# ...                                      ...
# fffc94f6ce00a00581880bf54a75a037           1
# fffcd46ef2263f404302a634eb57f7eb           1
# fffce4705a9662cd70adb13d4a31832d           1
# fffe18544ffabc95dfada21779c9644f           1
# fffe41c64501cc87c801fd61db3f6244           1
#
# [98666 rows x 1 columns]
